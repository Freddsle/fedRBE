# %% [markdown]
# # Results after correction:

# %%
cd /home/yuliya-cosybio/repos/cosybio/fedRBE

python evaluation_clusterization_after_correction/run_federated_kmeans_repetitions.py \
  --input-variant before_corrected \
  --start 1 --end 15 \
  --data-root /home/yuliya-cosybio/repos/cosybio/fedRBE/evaluation_data/simulated_rotation \
  --prepare-inputs \
  --restart-controller \
  --aggregate-output \
  --corrected-suffixes R_corrected

# %%
python evaluation_clusterization_after_correction/run_federated_kmeans_repetitions.py \
  --input-variant before \
  --start 1 --end 15 \
  --data-root /home/yuliya-cosybio/repos/cosybio/fedRBE/evaluation_data/simulated_rotation \
  --prepare-inputs \
  --restart-controller \
  --aggregate-output \
  --corrected-suffixes R_corrected
